# %% [markdown]
# # **IDS 576: Assignment 1**
#
# By:
#
# Aarjav Sanghvi[653527902] (asangh8@uic.edu)
#
# Aditya Chaudhari[653975298] (achaud61@uic.edu)
#
# Medhavi Pokhriyal [650144850] (mpokhr2@uic.edu)
#
# Rohith Kokkula[672724853] (rkokku2@uic.edu)

# %% [markdown]
# 1. Backpropagation (0.5pt)
# Draw the computation graph for the following function: 1/(1+(𝑎^b+c^d)∗𝑒)^2.
# Compute the gradient of the function with respect it to its inputs at (a,b,c,d,e) = (1,1,1,1,1)

# %% [markdown]
# Ans1)
#
# ![WhatsApp Image 2022-02-02 at 8.48.44 PM.jpeg](data:image/jpeg;base64,...)![WhatsApp Image 2022-02-02 at 8.49.25 PM.jpeg](data:image/jpeg;base64,...)![WhatsApp Image 2022-02-02 at 8.48.44 PM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# 2. Gradient Descent (2pt)
#
# a) Write a function to compute the mean squared error between a prediction and ground truth assuming both are numpy arrays (see python module numpy).
#
# b) Consider a model: y = mx + c , where the model parameter m = 1 and parameter c = 0 and x ∈ (0, 1) . Plot the function using matplotlib.
#
# c) Generate example data by drawing N = 100 uniform values from the range in which x lies, and compute the corresponding y to get {x,y) over i = 1 to N.
#
# d) Assuming that you do not know the model parameters, use backpropagation and gradient descent updates to find the model parameters (choose an appropriate learning rate). The loss function will be the mean squared error.
#
# e) Plot the error in the estimates as a function of the number of iterations of gradient update. Change the learning rate and plot another curve on the previous plot.
#
# f) Do steps 3-5 when the model is y = m1*x + m2*x^2 + c and the true parameters are m1 = 0.5, m2 = 1 and  c = 1. And x ∈ (0, 1). Also, plot the ground truth function (i.e., with the true values of m1, m2 and c). Compare and contrast the plot with the previous one.
#
# g) Do steps 3-5 when the model is y = tanh(m*x + c) and the true parameters are m = 1 and c = 2. And x ∈ (0, 2). Also, plot the ground truth function

# %%
#Function to compute mean sqaured error
import numpy as np
import sklearn
a = np.array([7, 2, 3])
b = np.array([5, 4, 3])
mse = np.square(np.subtract(a, b)).mean()
print(mse)
# Out:
# 2.6666666666666665

# %%
#Plot function using matplotlib after considering a model y=mx+c where m =1 and parameter c = 0
import matplotlib.pyplot as plt
x = np.linspace(0,1,100)
y = 1*x+0
plt.plot(x, y, '-r', label='y=1x+0')
plt.title('Graph of y=1x+0')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
#Example data 
from scipy.special import softmax
np.random.seed(123)
fig = plt.figure()

# example of calculating the softmax for a list of numbers
from scipy.special import softmax
np.random.seed(123)
fig = plt.figure()
#linear equation
m = 1
c = 0
Y = []
x = 0
num_examples = 100
#creating sample data
while x < 1:
  y = m*x + c
  Y.append(y)
  x += 0.01
x = np.arange(0, 1, 0.01)
#learning rate
lr = 1e-3
lr_2 = 1e-2
#starting with inital weights
W = 0
b = 0
length = len(Y)
iterations = 200
#Linear Equations
def h (W, b, x):
  return W * x + b
#Loss function
def loss (W, b, x, Y):
  return np.average(np.square(Y - h(W, b, x))) / 2
#Calculating gradient functions
def gradient (W, b, x, Y) :
  dW = - np.average((Y - h(W, b, x)) * x)
  db = - np.average(Y - h(W, b, x))
  return (dW, db)
loss_list1 = []
#Gradient Descent for learning rate 1
def gradient_descent (W, b, x, Y, lr, iterations) :
  for i in range(iterations) :
    dW, db = gradient (W, b, x, Y)
    W -= lr * dW
    b -= lr * db
    if i % 10 == 0 :
      print ('iteration : ', i, ' loss : ', loss(W, b, x, Y))
      loss_list1.append(loss(W, b, x, Y))
  return (W, b)
W, b = gradient_descent (W, b, x, Y, lr, iterations)

#Plotting the loss function
iterations = np.arange(0, 200, 10)
W, b
print(loss_list1)
plt.plot(iterations, loss_list1)
fig.suptitle('Linear Regression : Iterations v Loss', fontsize=18)
plt.xlabel('Iterations', fontsize=14)
plt.ylabel('Loss function', fontsize=14)
plt.show()

#Gradient Descent for learning rate 2
loss_list2 = []
iterations = 200
def gradient_descent (W, b, x, Y, lr_2, iterations) :
  for i in range(iterations) :
    dW, db = gradient (W, b, x, Y)
    W -= lr_2 * dW
    b -= lr_2 * db
    if i % 10 == 0 :
      print ('iteration : ', i, ' loss : ', loss(W, b, x, Y))
      loss_list2.append(loss(W, b, x, Y))
  return (W, b)
W, b = gradient_descent (W, b, x, Y, lr_2, iterations)

#Plotting the loss function for lr and lr_2
iterations = np.arange(0, 200, 10)
W, b
plt.plot(iterations, loss_list1, 'o', iterations, loss_list2, '-')
plt.legend(loc='upper left', labels=['learning rate 1', 'learning rate 2'])
fig.suptitle('Linear Regression : Error for learning rates 1 and 2', fontsize=18)
plt.xlabel('Iterations', fontsize=14)
plt.ylabel('Error', fontsize=14)
plt.xlim([0, 200])
plt.ylim([0, 0.2])
plt.show()
# Out:
# iteration :  0  loss :  0.1638223819442768
# iteration :  10  loss :  0.1603443218664032
# iteration :  20  loss :  0.15695222359502642
# iteration :  30  loss :  0.15364394375646118
# iteration :  40  loss :  0.15041739244497276
# iteration :  50  loss :  0.1472705318889484
# iteration :  60  loss :  0.14420137515034326
# iteration :  70  loss :  0.14120798485657032
# iteration :  80  loss :  0.13828847196402513
# iteration :  90  loss :  0.1354409945524557
# iteration :  100  loss :  0.13266375664940883
# iteration :  110  loss :  0.12995500708400237
# iteration :  120  loss :  0.12731303836929098
# iteration :  130  loss :  0.12473618561251353
# iteration :  140  loss :  0.12222282545252539
# iteration :  150  loss :  0.11977137502373812
# iteration :  160  loss :  0.11738029094590498
# iteration :  170  loss :  0.11504806833910754
# iteration :  180  loss :  0.11277323986331503
# iteration :  190  loss :  0.11055437478190282
# ...

# %%
#Do steps 3-5 when the model is y=m1x+m2x2+c and the true parameters are m1=0.5 ,
#Also, plot the ground truth function. Compare and contrast the plot with the previous
#linear equation
from sklearn import preprocessing
m1 = 0.5
m2 = 1
c = 1
Y = []
x = 0
num_examples = 100
lr = 1e-3
lr_2 = 1e-2

#Create Sample data 
while x < 1:
  y=m1*x + m2*x + c
  Y.append(y)
  x += 0.01
x = np.arange(0,1,0.01)

#Initial Weights 
m1 = 3
m2 = 0
c = 2
length = len(Y)
iterations = 200

#Linear Equations
def h (m1, m2, c, x):
  return m1 * x + m2 * x + c

#Loss function
def loss (m1, m2, c, x, Y):
  return np.average(np.square(Y - h(m1, m2, c, x))) / 2

#Calculating gradient functions
def gradient (m1, m2, c, x, Y) :
  dm1 = - np.average((Y - h(m1, m2, c, x)) * x)
  dm2 = - np.average((Y - h(m1, m2, c, x)) * x)
  dc = - np.average(Y - h(m1, m2, c, x))
  return (dm1, dm2, dc)
loss_list1 = []

#Gradient Descent for learning rate 1
def gradient_descent (m1, m2, c, x, Y, lr, iterations) :
  for i in range(iterations) :
    dm1, dm2, dc = gradient (m1, m2, c, x, Y)
    m1 -= lr * dm1
    m2 -= lr * dm2
    c -= lr * dc
    if i % 10 == 0 :
      print ('iteration : ', i, ' loss : ', loss(m1, m2, c, x, Y))
      loss_list1.append(loss(m1, m2, c, x, Y))
  return (m1, m2, c)
m1, m2, c = gradient_descent(m1, m2, c, x, Y, lr, iterations)

#Plotting the loss function
iterations = np.arange(0, 200, 10)
m1, m2, c
plt.plot(iterations, loss_list1)
fig.suptitle('Linear Regression : Iterations v Loss', fontsize=18)
plt.xlabel('Iterations', fontsize=14)
plt.ylabel('Loss function', fontsize=14)
plt.show()
loss_list2 = []
iterations = 200

#Gradient Descent for learning rate 2
def gradient_descent (m1, m2, c, x, Y, lr_2, iterations) :
  for i in range(iterations) :
    dm1, dm2, dc = gradient (m1, m2, c, x, Y)
    m1 -= lr_2 * dm1
    m2 -= lr_2 * dm2
    c -= lr_2 * dc
    if i % 10 == 0 :
      print ('iteration : ', i, ' loss : ', loss(m1, m2, c, x, Y))
      loss_list2.append(loss(m1, m2, c, x, Y))
  return (m1, m2, c)
m1, m2, c = gradient_descent(m1, m2, c, x, Y, lr_2, iterations)

#Plotting the loss function for lr and lr_2
iterations = np.arange(0, 200, 10)
plt.plot(iterations, loss_list1, 'o', iterations, loss_list2, '-')
plt.legend(loc='upper left', labels=['learning rate 1', 'learning rate 2'])
fig.suptitle('Linear Regression : Error for learning rates 1 and 2', fontsize=18)
plt.xlabel('Iterations', fontsize=14)
plt.ylabel('Error', fontsize=14)
plt.xlim([0, 200])
plt.ylim([0, 2])
plt.show()
# Out:
# iteration :  0  loss :  1.6069108946240975
# iteration :  10  loss :  1.5579228622503294
# iteration :  20  loss :  1.5104303144013789
# iteration :  30  loss :  1.4643875932034112
# iteration :  40  loss :  1.4197504347492613
# iteration :  50  loss :  1.3764759265396387
# iteration :  60  loss :  1.3345224662236834
# iteration :  70  loss :  1.293849721599208
# iteration :  80  loss :  1.2544185918341535
# iteration :  90  loss :  1.2161911698719825
# iteration :  100  loss :  1.1791307059848675
# iteration :  110  loss :  1.1432015724396225
# iteration :  120  loss :  1.1083692292424068
# iteration :  130  loss :  1.0746001909292762
# iteration :  140  loss :  1.0418619943706289
# iteration :  150  loss :  1.0101231675586173
# iteration :  160  loss :  0.9793531993474968
# iteration :  170  loss :  0.9495225101178181
# iteration :  180  loss :  0.9206024233362746
# iteration :  190  loss :  0.8925651379838367
# iteration :  0  loss :  0.8414472306869321
# ...

# %%
#Do steps 3-5 when the model is y=tanh(m∗x+c) and the true parameters are m=1 and
#linear equation
m = 1
c = 2
Y = []
x = 0
num_examples = 100

#creating sample data
while x < 2:
  y = np.tanh(m*x + c)
  Y.append(y)
  x += 0.02
x = np.arange(0, 2, 0.02)

#learning rate
lr = 1e-3
lr_2 = 1e-2

W = 0
b = 0
length = len(Y)
iterations = 200

#Linear Equation
def h (W, b, x):
  return np.tanh(W*x + c)

#Loss function
def loss (W, b, x, Y):
  return np.average(np.square(Y - h(W, b, x))) / 2

#Calculating gradient functions
def gradient (W, b, x, Y) :
  dW = - np.average((Y - h(W, b, x)) * x)
  db = - np.average(Y - h(W, b, x))
  return (dW, db)
loss_list1 = []
#GD for lr1
def gradient_descent (W, b, x, Y, lr, iterations) :
  for i in range(iterations) :
    dW, db = gradient (W, b, x, Y)
    W -= lr * dW
    b -= lr * db
    if i % 10 == 0 :
      print ('iteration : ', i, ' loss : ', loss(W, b, x, Y))
      loss_list1.append(loss(W, b, x, Y))
  return (W, b)
W, b = gradient_descent (W, b, x, Y, lr, iterations)

#GD for lr2
loss_list2 = []
iterations = 200
def gradient_descent (W, b, x, Y, lr_2, iterations) :
  for i in range(iterations) :
    dW, db = gradient (W, b, x, Y)
    W -= lr_2 * dW
    b -= lr_2 * db
    if i % 10 == 0 :
      print ('iteration : ', i, ' loss : ', loss(W, b, x, Y))
      loss_list2.append(loss(W, b, x, Y))
  return (W, b)
W, b = gradient_descent (W, b, x, Y, lr_2, iterations)

#Plotting the loss function for lr and lr_2
iterations = np.arange(0, 200, 10)
W, b
plt.plot(iterations, loss_list1, 'o', iterations, loss_list2, '-')
plt.legend(loc='upper left', labels=['learning rate 1', 'learning rate 2'])
fig.suptitle('Linear Regression : Error for learning rates 1 and 2', fontsize=18)
plt.xlabel('Iterations', fontsize=14)
plt.ylabel('Error', fontsize=14)
plt.xlim([0, 200])
plt.ylim([0, 0.001])
plt.show()
# Out:
# iteration :  0  loss :  0.0004052378732011215
# iteration :  10  loss :  0.00040453877784963477
# iteration :  20  loss :  0.0004038415656096873
# iteration :  30  loss :  0.00040314622959430473
# iteration :  40  loss :  0.00040245276294819673
# iteration :  50  loss :  0.00040176115884757826
# iteration :  60  loss :  0.0004010714104999975
# iteration :  70  loss :  0.0004003835111441643
# iteration :  80  loss :  0.00039969745404977523
# iteration :  90  loss :  0.0003990132325173455
# iteration :  100  loss :  0.00039833083987803823
# iteration :  110  loss :  0.0003976502694934966
# iteration :  120  loss :  0.00039697151475567556
# iteration :  130  loss :  0.000396294569086677
# iteration :  140  loss :  0.0003956194259385822
# iteration :  150  loss :  0.00039494607879329044
# iteration :  160  loss :  0.0003942745211623534
# iteration :  170  loss :  0.0003936047465868142
# iteration :  180  loss :  0.0003929367486370461
# iteration :  190  loss :  0.0003922705209125931
# ...

# %% [markdown]
# 3. ML Basics (0.5pt)
# Write a function to compute the (multiclass) logistic loss (also called the cross-entropy loss) given the parameters (W,b) of a linear model (as numpy arrays) and an example (x,y).
# Add an l1 regularization and an l2 regularization to the loss function.

# %%
import numpy as np #Represent ndarrays a.k.a. tensors
import matplotlib.pyplot as plt #For plotting
np.random.seed(0) #For repeatability of the experiment
import pickle #To read data for this experiment

#Setup
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
import numpy as np
import pickle
N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
X = np.zeros((N*K,D))
y = np.zeros(N*K, dtype='uint8')
for j in range(K):
  ix = range(N*j,N*(j+1))
  r = np.linspace(0.0,1,N) # radius
  t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2 # theta
  X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
  y[ix] = j

#Plot the data
fig = plt.figure()
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)

# %%
# Linear model

# Start with an initialize parameters randomly
W = 0.07 * np.random.randn(D,K)
b = np.zeros((1,K))

# Initial values from hyperparameter
reg = 1e-3 # regularization strength

#For simplicity, we will not optimize this using grid search here.

X.shape
# Out:
# (300, 2)

# %%
#Perform batch SGD using backprop

#For simplicity we will take the batch size to be the same as number of examples
num_examples = X.shape[0]

#Initial value for the Gradient Descent Parameter
step_size = 1e-0 #Also called learning rate

#For simplicity, we will not hand tune this algorithm parameter as well.

# gradient descent loop
for i in range(200):
  
    # evaluate class scores, [N x K]
    scores = np.dot(X, W) + b 
  
    # compute the class probabilities
    exp_scores = np.exp(scores)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True) # [N x K]
  
    # compute the loss: average cross-entropy loss and regularization
    corect_logprobs = -np.log(probs[range(num_examples),y])
    data_loss = np.sum(corect_logprobs)/num_examples
    reg_loss = 0.3*reg*np.sum(W*W)
    loss = data_loss + reg_loss
    if i % 10 == 0:
        print("iteration: "+str(i) +" loss: "+str(loss))
   # compute the gradient on scores
    dscores = probs
    dscores[range(num_examples),y] -= 1
    dscores /= num_examples
  
    # backpropate the gradient to the parameters (W,b)
    dW = np.dot(X.T, dscores)
    db = np.sum(dscores, axis=0, keepdims=True)
  
    dW += reg*W # regularization gradient
  
    # perform a parameter update
    W += -step_size * dW
    b += -step_size * db
# Out:
# iteration: 0 loss: 1.087452645000703
# iteration: 10 loss: 0.9140471112960118
# iteration: 20 loss: 0.8494280246976247
# iteration: 30 loss: 0.8203090119146055
# iteration: 40 loss: 0.8053582276196111
# iteration: 50 loss: 0.7969749792323825
# iteration: 60 loss: 0.7919723722433479
# iteration: 70 loss: 0.7888462901257611
# iteration: 80 loss: 0.7868221310366238
# iteration: 90 loss: 0.785473726664599
# iteration: 100 loss: 0.7845542316765606
# iteration: 110 loss: 0.7839146876639244
# iteration: 120 loss: 0.7834621626994536
# iteration: 130 loss: 0.7831370606984354
# iteration: 140 loss: 0.7829002700316331
# iteration: 150 loss: 0.7827256121943759
# iteration: 160 loss: 0.7825952643366721
# iteration: 170 loss: 0.7824969096236571
# iteration: 180 loss: 0.7824219220993891
# iteration: 190 loss: 0.7823641873062275

# %% [markdown]
# 4. Classification Pipeline (2.5pt)
#
# a) Generate data from Data_Linear_Classifier.ipynb (see the examples folder in the course repo).
#
# b) Split the data into test and train (20\%:80\%).
#
# c) Build a linear classifier assuming the multiclass logistic loss and l2 an regularization for the weights only. Report the prediction accuracy on the training data and the test data and show appropriate plots.
#
# d) Introduce a cross validation scheme and justify your choice of parameters. What is the validation accuracy compare to the test accuracy.
#
# e) What is the sensitivity of the model's performance to different learning rates and the number of gradient descent iterations. Describe via suitable plots.
#
# f) What is the sensitivity of the model's performance to different regularization parameter values. Find the best regularization parameter using an exhaustive search procedure. Describe your choice via suitable plots. What is the performance difference between using regularization and no regularization?
#
# g) What is the sensitivity of the model's performance with respect to a different test train split (e.g., 50\%:50\%).

# %%
#Imports
import numpy as np
import pickle
import pandas as p
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt #For plotting
from sklearn.linear_model import LogisticRegressionCV
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV

# %%
N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
X = np.zeros((N*K,D))
y = np.zeros(N*K, dtype='uint8')
for j in range(K):
  ix = range(N*j,N*(j+1))
  r = np.linspace(0.0,1,N) # radius
  t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2 # theta
  X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
  y[ix] = j


pickle.dump(X,open('dataX.pickle','wb'))
pickle.dump(y,open('dataY.pickle','wb'))

#Transforming the data to a dataframe
X = p.DataFrame(X)
y = p.DataFrame(y)

# Concating the data and labels into a single dataframe
data = p.concat([X,y],axis=1)
data.reindex(X.index)
data.columns = ['F1', 'F2', 'O_Class']

#Splitting the data as train (80%) and test (20%)
train, test = train_test_split(data, test_size=0.2)

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

fig = plt.figure()
plt.scatter(X[[0]], X[[1]], c=y, s=40, cmap=plt.cm.Spectral)

# %%
#Qn3. Building a linear classifier with logistic loss and l2 regularization on weights only

model = LogisticRegression(penalty='l2', solver = 'lbfgs', fit_intercept=True, multi_class='multinomial', 
                           tol=0.0001, C=1) 
model.fit(train[["F1","F2"]], train[["O_Class"]])

# Predicting for the training data and measuring accuracy
pred_training = model.predict(train[["F1","F2"]])
training_label = p.Series(train['O_Class'], index = train.index)
count_mis_training = (training_label != pred_training).sum()
print('Misclassified samples in train data: {}'.format(count_mis_training))
accuracy_training = metrics.accuracy_score(training_label, pred_training)
print('Training Accuracy: {:.2f}'.format(accuracy_training))

# Creating the confusion matrix
conmax1 = confusion_matrix(training_label,pred_training)
print('Confusion Matrix : {}'.format(conmax1))


b= model.intercept_
W = model.coef_.transpose()

pt = p.DataFrame(pred_training)
# Out:
# Misclassified samples in train data: 114
# Training Accuracy: 0.53
# Confusion Matrix : [[42 32  6]
#  [ 2 48 32]
#  [31 11 36]]
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
### Post training: plot the resulting classifier
h = 0.02
train['F1'].min()
x_min, x_max = train['F1'].min() - 1, train['F1'].max() + 1
y_min, y_max = train['F2'].min() - 1, train['F2'].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Z = np.dot(np.c_[xx.ravel(), yy.ravel()], W) + b
Z = np.argmax(Z, axis=1)
Z = Z.reshape(xx.shape)
fig = plt.figure()
plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(train[["F1"]], train[["F2"]], c=pt, s=40, cmap=plt.cm.Spectral)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
fig.savefig('spiral_linear.png')

# %%
# Predicting for test data and measuring accuracy
pred_testing = model.predict(test[["F1","F2"]])
test_lbl = p.Series(test['O_Class'], index = test.index)
count_mis_testing = (test_lbl != pred_testing).sum()
print('Misclassified samples in test data: {}'.format(count_mis_testing))
accuracy_testing = metrics.accuracy_score(test_lbl, pred_testing)
print('Test Accuracy: {:.2f}'.format(accuracy_testing))

# Creating the confusion matrix

conmax2 = confusion_matrix(test_lbl,pred_testing)
print('Confusion Matrix : {}'.format(conmax2))
# Out:
# Misclassified samples in test data: 36
# Test Accuracy: 0.40
# Confusion Matrix : [[ 9 10  1]
#  [ 3  7  8]
#  [14  0  8]]

# %%
### Post testing: plot the resulting classifier
pt1 = p.DataFrame(pred_testing)

h = 0.02
test['F1'].min()
x_min, x_max = test['F1'].min() - 1, test['F1'].max() + 1
y_min, y_max = test['F2'].min() - 1, test['F2'].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Z = np.dot(np.c_[xx.ravel(), yy.ravel()], W) + b
Z = np.argmax(Z, axis=1)
Z = Z.reshape(xx.shape)
fig = plt.figure()
plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(test[["F1"]], test[["F2"]], c=pt1, s=40, cmap=plt.cm.Spectral)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
fig.savefig('spiral_linear.png')

# %%
#Qn 6. To find the best regularisation parameter using gridsearch
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000] }
newmodel = GridSearchCV(LogisticRegression(penalty='l2', solver='lbfgs', fit_intercept=True, multi_class='multinomial', tol=0.0001), param_grid, cv=5)
newmodel.fit(train[["F1","F2"]], train[["O_Class"]])

C1 = ['0.001', '0.01', '0.1', '1', '10', '100', '1000']

scores1 = newmodel.cv_results_['mean_test_score']
scores1 = np.array(scores1)


# Predicting for train data and measuring accuracy

pred_training3 = newmodel.predict(train[["F1","F2"]])
training_label = p.Series(train['O_Class'], index = train.index)
count_mis_training3 = (training_label != pred_training3).sum()
print('Misclassified samples in train data: {}'.format(count_mis_training3))
accuracy_training3 = metrics.accuracy_score(training_label, pred_training3)
print('Training Accuracy: {:.2f}'.format(accuracy_training3))

conmax6 = confusion_matrix(training_label,pred_training3)
print('Confusion Matrix : {}'.format(conmax6))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
# Sensitivity measurement for all the 3 classes
sens_0 = round(conmax6[0,0]/float(conmax6[0,0]+conmax6[0,1]+conmax6[0,2]),2)
print('Sensitivity for Class 0 : {}'.format(sens_0))

sens_1 = round(conmax6[1,1]/float(conmax6[1,0]+conmax6[1,1]+conmax6[1,2]),2)
print('Sensitivity for Class 1 : {}'.format(sens_1))

sens_2 = round(conmax6[2,2]/float(conmax6[2,0]+conmax6[2,1]+conmax6[2,2]),2)
print('Sensitivity for Class 2 : {}'.format(sens_2))
# Out:
# Sensitivity for Class 0 : 0.54
# Sensitivity for Class 1 : 0.91
# Sensitivity for Class 2 : 0.4

# %%
# Predicting for test data and measuring accuracy

pred_testing3 = newmodel.predict(test[["F1","F2"]])
testing_label = p.Series(test['O_Class'], index = test.index)
count_mis_testing3 = (testing_label != pred_testing3).sum()
print('Misclassified samples in train data: {}'.format(count_mis_testing3))
accuracy_testing3 = metrics.accuracy_score(test_lbl, pred_testing3)
print('Training Accuracy: {:.2f}'.format(accuracy_testing3))

conmax7 = confusion_matrix(testing_label,pred_testing3)
print('Confusion Matrix : {}'.format(conmax7))
# Out:
# Misclassified samples in train data: 30
# Training Accuracy: 0.50
# Confusion Matrix : [[ 9 10  1]
#  [ 1 14  3]
#  [12  3  7]]

# %%
# Sensitivity measurement for all classes

sens_0 = round(conmax7[0,0]/float(conmax7[0,0]+conmax7[0,1]+conmax7[0,2]),2)
print('Sensitivity for Class 0 : {}'.format(sens_0))

sens_1 = round(conmax7[1,1]/float(conmax7[1,0]+conmax7[1,1]+conmax7[1,2]),2)
print('Sensitivity for Class 1 : {}'.format(sens_1))

sens_2 = round(conmax7[2,2]/float(conmax7[2,0]+conmax7[2,1]+conmax7[2,2]),2)
print('Sensitivity for Class 2 : {}'.format(sens_2))
# Out:
# Sensitivity for Class 0 : 0.45
# Sensitivity for Class 1 : 0.78
# Sensitivity for Class 2 : 0.32

# %%
# Building logistic model without no regularisation by setting C=2000

model3 = LogisticRegression(penalty='l2', solver = 'lbfgs', fit_intercept=True, multi_class='multinomial', 
                           tol=0.0001, C=2000) 
model3.fit(train[["F1","F2"]], train[["O_Class"]])

# Predicting for train data and measuring accuracy
pred_training4 = model3.predict(train[["F1","F2"]])
training_label = p.Series(train['O_Class'], index = train.index)
count_mis_training4 = (training_label != pred_training4).sum()
print('Misclassified samples in train data: {}'.format(count_mis_training4))
accuracy_training4 = metrics.accuracy_score(training_label, pred_training4)
print('Training Accuracy: {:.2f}'.format(accuracy_training4))

conmax8 = confusion_matrix(training_label,pred_training4)
print('Confusion Matrix : {}'.format(conmax8))
# Out:
# Misclassified samples in train data: 113
# Training Accuracy: 0.53
# Confusion Matrix : [[42 31  7]
#  [ 2 47 33]
#  [31  9 38]]
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Sensitivity measurement for all classes

sens_0 = round(conmax8[0,0]/float(conmax8[0,0]+conmax8[0,1]+conmax8[0,2]),2)
print('Sensitivity for Class 0 : {}'.format(sens_0))

sens_1 = round(conmax8[1,1]/float(conmax8[1,0]+conmax8[1,1]+conmax8[1,2]),2)
print('Sensitivity for Class 1 : {}'.format(sens_1))

sens_2 = round(conmax8[2,2]/float(conmax8[2,0]+conmax8[2,1]+conmax8[2,2]),2)
print('Sensitivity for Class 2 : {}'.format(sens_2))
# Out:
# Sensitivity for Class 0 : 0.52
# Sensitivity for Class 1 : 0.57
# Sensitivity for Class 2 : 0.49

# %%
# Predicting for test data and measuring accuracy

pred_testing4 = model3.predict(test[["F1","F2"]])
testing_label = p.Series(test['O_Class'], index = test.index)
count_mis_testing4 = (testing_label != pred_testing4).sum()
print('Misclassified samples in test data: {}'.format(count_mis_testing4))
accuracy_testing4 = metrics.accuracy_score(test_lbl, pred_testing4)
print('Test Accuracy: {:.2f}'.format(accuracy_testing4))

# Creating the confusion matrix

conmax9 = confusion_matrix(testing_label,pred_testing4)
print('Confusion Matrix : {}'.format(conmax9))
# Out:
# Misclassified samples in test data: 35
# Test Accuracy: 0.42
# Confusion Matrix : [[ 9  9  2]
#  [ 3  7  8]
#  [13  0  9]]

# %%
#Qn4. Building a linear classifier with logistic loss and cross validation
model1 = LogisticRegressionCV(Cs=100, cv=20, penalty='l2', solver = 'lbfgs', fit_intercept=True, multi_class='multinomial', 
                           tol=0.0001)
model1.fit(train[["F1","F2"]], train[["O_Class"]])

# Predicting for test data after cross validation and measuring accuracy
pred_testing1 = model1.predict(test[["F1","F2"]])
testing_label = p.Series(test['O_Class'], index = test.index)
count_mis_testing1 = (testing_label != pred_testing1).sum()
print('Misclassified samples in test data: {}'.format(count_mis_testing1))
accuracy_testing1 = metrics.accuracy_score(test_lbl, pred_testing1)
print('Test Accuracy: {:.2f}'.format(accuracy_testing1))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Misclassified samples in test data: 27
# Test Accuracy: 0.55

# %%
#Qn5. Building a logistic regression model using gradient descent and having learning rate

np.random.seed(12345678)
#param_mi = {'max_iter': [1,500,1000,1500,2000,2500,3000,3500,4000,4500,5000,
#                         5500,6000,6500,7000,7500,8000,8500,9000,9500,10000] }

param_alpha = {'alpha': [0.0001,0.001,0.01,0.1,1,5,10,50,100] }

model2 = GridSearchCV(SGDClassifier(max_iter=5000, average=False, class_weight=None, early_stopping=False, epsilon=0.1, eta0=0.1, fit_intercept=True,
    l1_ratio=0.15, learning_rate='optimal', loss='log', n_iter_no_change=5, n_jobs=None, penalty='l2',
    power_t=0.5, random_state=None, shuffle=True, tol=0.001, validation_fraction=0.1, verbose=0, warm_start=False),param_alpha,cv=2)
model2.fit(train[["F1","F2"]], train[["O_Class"]])

max_iter1 = ['0.0001','0.001','0.01','0.1','1','5','10','50','100']

scores = model2.cv_results_['mean_test_score']
scores = np.array(scores)



model2.best_estimator_
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
# Predicting for train data and measuring accuracy

pred_training2 = model2.predict(train[["F1","F2"]])
training_label = p.Series(train['O_Class'], index = train.index)
count_mis_training2 = (training_label != pred_training2).sum()
print('Misclassified samples in train data: {}'.format(count_mis_training))
accuracy_training2 = metrics.accuracy_score(training_label, pred_training2)
print('Training Accuracy: {:.2f}'.format(accuracy_training2))

# Creating confusion matrix
conmax4 = confusion_matrix(training_label,pred_training2)
print('Confusion Matrix : {}'.format(conmax4))
# Out:
# Misclassified samples in train data: 114
# Training Accuracy: 0.56
# Confusion Matrix : [[39 35  6]
#  [ 0 58 24]
#  [20 21 37]]

# %%
# Sensitivity measurement for all classes

sens_0 = round(conmax4[0,0]/float(conmax4[0,0]+conmax4[0,1]+conmax4[0,2]),2)
print('Sensitivity for Class 0 : {}'.format(sens_0))

sens_1 = round(conmax4[1,1]/float(conmax4[1,0]+conmax4[1,1]+conmax4[1,2]),2)
print('Sensitivity for Class 1 : {}'.format(sens_1))

sens_2 = round(conmax4[2,2]/float(conmax4[2,0]+conmax4[2,1]+conmax4[2,2]),2)
print('Sensitivity for Class 2 : {}'.format(sens_2))
# Out:
# Sensitivity for Class 0 : 0.49
# Sensitivity for Class 1 : 0.71
# Sensitivity for Class 2 : 0.47

# %% [markdown]
# 5. Feedforward Neural Networks (2.5pt)
# Consider two models:
# (a) a 2-layer feedforward neural network (i.e., 1 hidden layer with
# f(𝑥, 𝑊1, 𝑏1 , 𝑊2, 𝑏2 ) = 𝑊2 max(0, 𝑊1𝑥 + 𝑏1 ) + 𝑏2), and
# (b) same as before but with leaky ReLU f(x) = x if x > 0 else f(x) = 0.01*x
#
# Build the above classifiers using Keras and Tensorflow and solve the classification problem for MNIST/Fashion MNIST.
# Discuss how optimizer choice influences performance.
# What happens when the number of hidden units chosen is much smaller. Similarly, what happens when the number of hidden units chosen is much higher?

# %%
import tensorflow as tf

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
import keras
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# Model Building
#
# We are building a two layer neural network model where the initial layer is is the imput layer which has been derived from the 28*28 image pixels. The second layer is a dense layer consisting of 128 nodes. The Final layer is the output layer where we are predicting into th 10 classes For the activation fucntion we have used the Leaky Relu activation which we can get from the keras library

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation=keras.layers.LeakyReLU(alpha=0.01)),
    tf.keras.layers.Dense(10)
])

# %% [markdown]
# Optimizer Performance
#
# We are going to compare 3 different optimizers which are adam, SGD, RMSProp.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4942 - accuracy: 0.8253
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3747 - accuracy: 0.8648
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3391 - accuracy: 0.8759
# Epoch 4/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3144 - accuracy: 0.8853
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2976 - accuracy: 0.8893
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2824 - accuracy: 0.8950
# Epoch 7/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2695 - accuracy: 0.8996
# Epoch 8/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2581 - accuracy: 0.9028
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2489 - accuracy: 0.9064
# Epoch 10/10
# ...

# %%
model.compile(optimizer='SGD',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2011 - accuracy: 0.9259
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1947 - accuracy: 0.9274
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1919 - accuracy: 0.9286
# Epoch 4/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1902 - accuracy: 0.9284
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1887 - accuracy: 0.9300
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1875 - accuracy: 0.9297
# Epoch 7/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1868 - accuracy: 0.9306
# Epoch 8/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1856 - accuracy: 0.9308
# Epoch 9/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1848 - accuracy: 0.9304
# Epoch 10/10
# ...

# %%
model.compile(optimizer='RMSprop',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2314 - accuracy: 0.9145
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2294 - accuracy: 0.9150
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2278 - accuracy: 0.9181
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2248 - accuracy: 0.9190
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2235 - accuracy: 0.9202
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2195 - accuracy: 0.9211
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2181 - accuracy: 0.9222
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2141 - accuracy: 0.9237
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2132 - accuracy: 0.9247
# Epoch 10/10
# ...

# %% [markdown]
# ON looking at the final accuracy scores we see that 'SGD' optimizer performs better than RMSprop and adam

# %% [markdown]
# Changing the number of Hidden Units
#
# Case 1- When number of hidden units is much smaller
#
# We see that accuracy is lower, it may be because we are underfitting the model as there are not many nodes over which the data can be fitted

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(32, activation=keras.layers.LeakyReLU(alpha=0.01)),
    tf.keras.layers.Dense(10)
])
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5443 - accuracy: 0.8140
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4123 - accuracy: 0.8556
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3859 - accuracy: 0.8633
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3641 - accuracy: 0.8703
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3495 - accuracy: 0.8747
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3354 - accuracy: 0.8781
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3239 - accuracy: 0.8837
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3148 - accuracy: 0.8856
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3073 - accuracy: 0.8890
# Epoch 10/10
# ...

# %% [markdown]
# Case 2- When the number of nodes is much larger
#
# Although we have increased the number of nodes, we notice that there is no significant increase in the training accuracy which may be because there is no depth to the neural network model.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(512, activation=keras.layers.LeakyReLU(alpha=0.01)),
    tf.keras.layers.Dense(10)
])
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.4788 - accuracy: 0.8286
# Epoch 2/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3581 - accuracy: 0.8686
# Epoch 3/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3244 - accuracy: 0.8808
# Epoch 4/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3000 - accuracy: 0.8881
# Epoch 5/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2806 - accuracy: 0.8955
# Epoch 6/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2672 - accuracy: 0.8998
# Epoch 7/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2555 - accuracy: 0.9050
# Epoch 8/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2430 - accuracy: 0.9097
# Epoch 9/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2336 - accuracy: 0.9120
# Epoch 10/10
# ...

# %% [markdown]
# **Summary**
#
# We notice that we need to further add layers if we want to increase the performance
